# %%
# %load_ext autoreload
# %autoreload 2

from GettingStarted_lib.config_manager import ConfigManager
from GettingStarted_lib.Interface import Interface
from GettingStarted_lib.LaserLockingController import LaserLockingController
import pprint

# %%
# 1. Use ConfigManager to get settings
CM = ConfigManager()
board = CM.get_board("RedPitaya_K")
user, pw = CM.get_credentials("RedPitaya_K")
# 2. Pass settings to Interface
I = Interface(
    host=board.ip,
    linien_port=board.linien_port,
    username=user,
    password=pw
)
LLC = LaserLockingController(I)
# Out:
# 2026-01-21 14:09:44 - Interface - INFO - Attempting connection to 192.168.1.159:18862
# linien_client.connection       INFO     Try to connect to 192.168.1.159:18862
# linien_client.connection       DEBUG    Sent authentication hash
# linien_client.connection       INFO     Connection established!
# 2026-01-21 14:09:47 - Interface - INFO - Connected to device at 192.168.1.159
# 2026-01-21 14:09:48 - DataHandler - INFO - All reference lines loaded successfully.
# 2026-01-21 14:09:48 - LaserLockingController - INFO - LaserLockController initialized successfully.

# %%
LLC.scan(0.9, 1.0, 10)
# Out:
# 2026-01-21 14:11:01 - LaserLockingController - INFO - Starting scan from 0.9V to 1.0V with 10 points.
# Scanning at voltage 1.000V (10/10) [##########] (13.52s) Done!
# 2026-01-21 14:11:15 - LaserLockingController - INFO - Scan completed successfully.

# %%
LLC.save_reference_line(key = 'K_D2', V_scan = 0.933, start_voltage=0.05, stop_voltage=0.6, V_lock_start = 0.35, V_lock_end = 0.5, offset=0.002)
# Out:
# 2026-01-21 14:14:40 - LaserLockingController - INFO - Saving reference line with key K_D2.
# 2026-01-21 14:14:40 - DataHandler - INFO - Saved reference line: REFERENCE_LINE_K_D2.npy
# 2026-01-21 14:14:40 - DataHandler - INFO - All reference lines loaded successfully.
# 2026-01-21 14:14:41 - LaserLockingController - INFO - Reference line K_D2 saved successfully.

# %%
LLC.automatic_lock_relock('LINE_K_D2')
# Out:
# 2026-01-21 14:17:17 - LaserLockingController - INFO - Line LINE_K_D2 is centered at offset 0.9645714285714285.
# Started autolock
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 LLC.automatic_lock_relock('LINE_K_D2')
#
# File ~/Desktop/Simone_Damian/Serafini/GettingStarted_lib/LaserLockingController.py:710, in LaserLockingController.automatic_lock_relock(self, line_name, relock)
#     708 self.find_reference_lines(self.hardware_interface.get_remote_value('big_offset') - 0.02, self.hardware_interface.get_remote_value('big_offset') + 0.02, 6)
#     709 try:
# --> 710     self.center_and_lock_v1(line_name)
#     711 except Exception:
#     712     self.logger.error("Automatic relock failed...")
#
# File ~/Desktop/Simone_Damian/Serafini/GettingStarted_lib/LaserLockingController.py:664, in LaserLockingController.center_and_lock_v1(self, line_name)
#     662 print("Started autolock")
#     663 try:
# --> 664     self.hardware_interface.wait_for_lock_status(True)
#     665     self.logger.info("Locking the laser worked \o/")
#     666     sleep(2)
#
# File ~/Desktop/Simone_Damian/Serafini/GettingStarted_lib/Interface.py:152, in Interface.wait_for_lock_status(self, should_be_locked)
#     150 if counter > 20:
#     151     raise Exception("Waited too long for lock status change.")
# --> 152 sleep(0.5)
#
# KeyboardInterrupt:

# %%
I.start_sweep()
